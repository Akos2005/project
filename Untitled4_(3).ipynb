# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt

tf.config.threading.set_intra_op_parallelism_threads(6)

dataset_path = 'E:\project\img'     

try:
    image_height = 100
    image_width = 200
    batch_size = 8
    
    dataset = tf.keras.utils.image_dataset_from_directory(
        dataset_path,
        labels='inferred',
        label_mode='categorical',
        image_size=(image_height, image_width),
        interpolation='lanczos3',
        batch_size=batch_size,
        shuffle=True,
        seed=42
    ) 

    print(f"Total batches: {len(dataset)}") 
    
    plt.figure(figsize=(10, 10))
    for images, labels in dataset.take(1):
        for i in range(min(9, len(images))):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            predicted_class_index = np.argmax(labels[i].numpy())
            plt.title(dataset.class_names[predicted_class_index])
            plt.axis("off")
    plt.show() 

except Exception as e:
    print(f"error {e}")
# Out:
# Found 93 files belonging to 9 classes.
# Total batches: 12

# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt

base_dataset_path = 'E:\\project\\dataset'

image_height = 100
image_width = 200
batch_size = 128

def load_dataset_split_main(split_name, label_mode='categorical'):
    split_path = os.path.join(base_dataset_path, split_name, 'images')
    if not os.path.exists(split_path):
        print(f"Warning: Split path '{split_path}' not found. Skipping {split_name} dataset loading.")
        return None

    print(f"Loading {split_name} dataset from: {split_path}")
    dataset = tf.keras.utils.image_dataset_from_directory(
        split_path,
        labels='inferred',
        label_mode=label_mode,
        image_size=(image_height, image_width),
        interpolation='lanczos3',
        batch_size=batch_size,
        shuffle=(split_name == 'train'),
        seed=42 if split_name == 'train' else None
    )
    print(f"  {split_name} dataset created with {len(dataset.class_names)} classes: {dataset.class_names}")
    print(f"  Total batches: {len(dataset)}")
    return dataset

train_ds_full = load_dataset_split_main('train')
val_ds_full = load_dataset_split_main('val')
test_ds_full = load_dataset_split_main('test')


if train_ds_full:
    class_names = train_ds_full.class_names
    num_classes = len(class_names)
else:
    class_names = []
    num_classes = 0

if train_ds_full:
    plt.figure(figsize=(12, 12))
    plt.suptitle("Sample Images")

    selected_images = []
    selected_labels = []
    found_classes = set()

    for images, labels in train_ds_full.take(num_classes * 2):
        for i in range(len(images)):
            predicted_class_index = np.argmax(labels[i].numpy())
            class_name = class_names[predicted_class_index]

            if class_name not in found_classes:
                selected_images.append(images[i].numpy().astype("uint8"))
                selected_labels.append(class_name)
                found_classes.add(class_name)

            if len(found_classes) == num_classes:
                break
        if len(found_classes) == num_classes:
            break


    for i in range(min(num_classes, len(selected_images))):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(selected_images[i])
        plt.title(selected_labels[i])
        plt.axis("off")
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
# Out:
# Loading train dataset from: E:\project\dataset\train\images
# Found 431973 files belonging to 9 classes.
#   train dataset created with 9 classes: ['CLEAN', 'CROSS', 'DIAGONAL', 'DOUBLE_LINE', 'MIXED', 'SCRATCH', 'SINGLE_LINE', 'WAVE', 'ZIG_ZAG']
#   Total batches: 3375
# Loading val dataset from: E:\project\dataset\val\images
# Found 68031 files belonging to 9 classes.
#   val dataset created with 9 classes: ['CLEAN', 'CROSS', 'DIAGONAL', 'DOUBLE_LINE', 'MIXED', 'SCRATCH', 'SINGLE_LINE', 'WAVE', 'ZIG_ZAG']
#   Total batches: 532
# Loading test dataset from: E:\project\dataset\test\images
# Found 182754 files belonging to 9 classes.
#   test dataset created with 9 classes: ['CLEAN', 'CROSS', 'DIAGONAL', 'DOUBLE_LINE', 'MIXED', 'SCRATCH', 'SINGLE_LINE', 'WAVE', 'ZIG_ZAG']
#   Total batches: 1428

# %%
dataset_size = len(dataset)
train_size = int(0.7 * dataset_size)
val_size = int(0.15 * dataset_size)
test_size = dataset_size - train_size - val_size

train_ds = dataset.take(train_size)
remaining_ds = dataset.skip(train_size)
val_ds = remaining_ds.take(val_size)
test_ds = remaining_ds.skip(val_size)

print(f"Dataset split into: ")
print(f"  Training: {len(train_ds)} batches")
print(f"  Validation: {len(val_ds)} batches")
print(f"  Test: {len(test_ds)} batches")
# Out:
# Dataset split into:
#   Training: 8 batches
#   Validation: 1 batches
#   Test: 3 batches

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Prepare the full datasets with caching and prefetching
train_ds_full = train_ds_full.shuffle(100).prefetch(buffer_size=AUTOTUNE)
val_ds_full = val_ds_full.prefetch(buffer_size=AUTOTUNE)
test_ds_full = test_ds_full.prefetch(buffer_size=AUTOTUNE)

print("Full datasets prepared with caching and prefetching.")
# Out:
# Full datasets prepared with caching and prefetching.

# %%
import tensorflow as tf

tf.keras.mixed_precision.set_global_policy('mixed_float16')
num_classes = len(class_names) # Correctly use class_names from the full dataset
print(f"Number of classes for model output: {num_classes}")

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255, input_shape=(image_height, image_width, 3)),
  tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# Number of classes for model output: 9
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 100, 200, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 100, 200, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 50, 100, 16)      0
#  2D)
#
#  dropout_4 (Dropout)         (None, 50, 100, 16)       0
#
#  conv2d_4 (Conv2D)           (None, 50, 100, 32)       4640
#
#  max_pooling2d_4 (MaxPooling  (None, 25, 50, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 25, 50, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 25, 50, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 25, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 12, 25, 64)        0
#
#  flatten_1 (Flatten)         (None, 19200)             0
#
#  dense_2 (Dense)             (None, 128)               2457728
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 2,482,473
# Trainable params: 2,482,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

print("Verzió:", tf.__version__)
print("Elérhető eszközök:", tf.config.list_physical_devices())
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print(f"GPU elérhető: {gpu_devices}")
else:
    print("A TensorFlow NEM látja a GPU-t. CPU-n fog futni.")
# Out:
# Verzió: 2.10.0
# Elérhető eszközök: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU elérhető: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
epochs = 40
history = model.fit(
    train_ds_full,
    validation_data=val_ds_full,
    epochs=epochs
)

print("Model training complete with full dataset.")
# Out:
# Epoch 1/40
# 3375/3375 [==============================] - 411s 119ms/step - loss: 1.2772 - accuracy: 0.5166 - val_loss: 0.8678 - val_accuracy: 0.6830
# Epoch 2/40
# 3375/3375 [==============================] - 407s 119ms/step - loss: 0.9711 - accuracy: 0.6270 - val_loss: 0.7995 - val_accuracy: 0.7068
# Epoch 3/40
# 3375/3375 [==============================] - 407s 119ms/step - loss: 0.8932 - accuracy: 0.6595 - val_loss: 0.7756 - val_accuracy: 0.7119
# Epoch 4/40
# 3375/3375 [==============================] - 406s 118ms/step - loss: 0.8462 - accuracy: 0.6785 - val_loss: 0.7602 - val_accuracy: 0.7210
# Epoch 5/40
# 3375/3375 [==============================] - 407s 119ms/step - loss: 0.8168 - accuracy: 0.6913 - val_loss: 0.7247 - val_accuracy: 0.7331
# Epoch 6/40
# 3375/3375 [==============================] - 407s 119ms/step - loss: 0.7970 - accuracy: 0.6992 - val_loss: 0.7304 - val_accuracy: 0.7339
# Epoch 7/40
# 3375/3375 [==============================] - 412s 120ms/step - loss: 0.7834 - accuracy: 0.7049 - val_loss: 0.7149 - val_accuracy: 0.7376
# Epoch 8/40
# 3375/3375 [==============================] - 399s 116ms/step - loss: 0.7722 - accuracy: 0.7105 - val_loss: 0.7400 - val_accuracy: 0.7313
# Epoch 9/40
# 3375/3375 [==============================] - 391s 114ms/step - loss: 0.7580 - accuracy: 0.7175 - val_loss: 0.7181 - val_accuracy: 0.7380
# Epoch 10/40
# 3375/3375 [==============================] - 385s 112ms/step - loss: 0.7509 - accuracy: 0.7208 - val_loss: 0.6951 - val_accuracy: 0.7458
# Epoch 11/40
# 3375/3375 [==============================] - 385s 112ms/step - loss: 0.7434 - accuracy: 0.7242 - val_loss: 0.7008 - val_accuracy: 0.7433
# Epoch 12/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.7397 - accuracy: 0.7262 - val_loss: 0.6919 - val_accuracy: 0.7495
# Epoch 13/40
# 3375/3375 [==============================] - 385s 112ms/step - loss: 0.7295 - accuracy: 0.7300 - val_loss: 0.6969 - val_accuracy: 0.7449
# Epoch 14/40
# 3375/3375 [==============================] - 385s 112ms/step - loss: 0.7295 - accuracy: 0.7302 - val_loss: 0.6786 - val_accuracy: 0.7539
# Epoch 15/40
# 3375/3375 [==============================] - 385s 112ms/step - loss: 0.7245 - accuracy: 0.7325 - val_loss: 0.6913 - val_accuracy: 0.7512
# Epoch 16/40
# 3375/3375 [==============================] - 385s 112ms/step - loss: 0.7221 - accuracy: 0.7335 - val_loss: 0.6863 - val_accuracy: 0.7506
# Epoch 17/40
# 3375/3375 [==============================] - 385s 112ms/step - loss: 0.7203 - accuracy: 0.7343 - val_loss: 0.6691 - val_accuracy: 0.7580
# Epoch 18/40
# 3375/3375 [==============================] - 386s 113ms/step - loss: 0.7182 - accuracy: 0.7342 - val_loss: 0.6847 - val_accuracy: 0.7507
# Epoch 19/40
# 3375/3375 [==============================] - 382s 111ms/step - loss: 0.7156 - accuracy: 0.7359 - val_loss: 0.6756 - val_accuracy: 0.7548
# Epoch 20/40
# 3375/3375 [==============================] - 382s 111ms/step - loss: 0.7119 - accuracy: 0.7375 - val_loss: 0.6740 - val_accuracy: 0.7553
# Epoch 21/40
# 3375/3375 [==============================] - 381s 111ms/step - loss: 0.7106 - accuracy: 0.7385 - val_loss: 0.6773 - val_accuracy: 0.7560
# Epoch 22/40
# 3375/3375 [==============================] - 381s 111ms/step - loss: 0.7066 - accuracy: 0.7401 - val_loss: 0.6791 - val_accuracy: 0.7532
# Epoch 23/40
# 3375/3375 [==============================] - 382s 111ms/step - loss: 0.7061 - accuracy: 0.7407 - val_loss: 0.6692 - val_accuracy: 0.7582
# Epoch 24/40
# 3375/3375 [==============================] - 382s 111ms/step - loss: 0.7035 - accuracy: 0.7414 - val_loss: 0.6683 - val_accuracy: 0.7580
# Epoch 25/40
# 3375/3375 [==============================] - 382s 111ms/step - loss: 0.7015 - accuracy: 0.7422 - val_loss: 0.6701 - val_accuracy: 0.7569
# Epoch 26/40
# 3375/3375 [==============================] - 382s 112ms/step - loss: 0.7035 - accuracy: 0.7416 - val_loss: 0.6670 - val_accuracy: 0.7592
# Epoch 27/40
# 3375/3375 [==============================] - 387s 113ms/step - loss: 0.6976 - accuracy: 0.7437 - val_loss: 0.6761 - val_accuracy: 0.7580
# Epoch 28/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.7139 - accuracy: 0.7388 - val_loss: 0.6841 - val_accuracy: 0.7553
# Epoch 29/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6871 - accuracy: 0.7498 - val_loss: 0.6743 - val_accuracy: 0.7573
# Epoch 30/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6765 - accuracy: 0.7532 - val_loss: 0.6686 - val_accuracy: 0.7579
# Epoch 31/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6746 - accuracy: 0.7543 - val_loss: 0.6687 - val_accuracy: 0.7611
# Epoch 32/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6737 - accuracy: 0.7547 - val_loss: 0.6696 - val_accuracy: 0.7607
# Epoch 33/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6755 - accuracy: 0.7546 - val_loss: 0.6626 - val_accuracy: 0.7612
# Epoch 34/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6684 - accuracy: 0.7562 - val_loss: 0.6647 - val_accuracy: 0.7613
# Epoch 35/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6660 - accuracy: 0.7574 - val_loss: 0.6630 - val_accuracy: 0.7634
# Epoch 36/40
# 3375/3375 [==============================] - 386s 113ms/step - loss: 0.6657 - accuracy: 0.7578 - val_loss: 0.6565 - val_accuracy: 0.7634
# Epoch 37/40
# 3375/3375 [==============================] - 862s 253ms/step - loss: 0.6638 - accuracy: 0.7587 - val_loss: 0.6617 - val_accuracy: 0.7618
# Epoch 38/40
# 3375/3375 [==============================] - 418s 117ms/step - loss: 0.6627 - accuracy: 0.7589 - val_loss: 0.6525 - val_accuracy: 0.7657
# Epoch 39/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6624 - accuracy: 0.7590 - val_loss: 0.6706 - val_accuracy: 0.7604
# Epoch 40/40
# 3375/3375 [==============================] - 384s 112ms/step - loss: 0.6615 - accuracy: 0.7597 - val_loss: 0.6590 - val_accuracy: 0.7632
# Model training complete with full dataset.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='training accuracy')
plt.plot(epochs_range, val_acc, label='validation accuracy')
plt.legend(loc='lower right')
plt.title('training and validation accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='training loss')
plt.plot(epochs_range, val_loss, label='validation loss')
plt.legend(loc='upper right')
plt.title('training and validation loss')
plt.show()

# %%
print("Evaluating model on the test dataset...")
loss, accuracy = model.evaluate(test_ds_full)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Evaluating model on the test dataset...
# 1428/1428 [==============================] - 333s 233ms/step - loss: 2.8527 - accuracy: 0.4749
# Test Loss: 2.8527
# Test Accuracy: 0.4749

# %%
print("Evaluating model on the small-scale 'img' test dataset...")
loss_small, accuracy_small = model.evaluate(dataset)

print(f"Small-scale Test Loss: {loss_small:.4f}")
print(f"Small-scale Test Accuracy: {accuracy_small:.4f}")
# Out:
# Evaluating model on the small-scale 'img' test dataset...
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2659 - accuracy: 0.8495
# Small-scale Test Loss: 0.2659
# Small-scale Test Accuracy: 0.8495

# %%
import numpy as np
import tensorflow as tf

tf.keras.mixed_precision.set_global_policy('float32')
num_classes_model = model.layers[-1].output_shape[-1]
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

dataset_shuffled = dataset.shuffle(buffer_size=64)

history_fine = model.fit(
    dataset_shuffled,
    epochs=50,
    verbose=1
)

for images, labels in dataset_shuffled.take(1):
    preds = model.predict(images)
    for i in range(min(5, len(images))):
        true_idx = np.argmax(labels[i])
        pred_idx = np.argmax(preds[i])
        conf = preds[i][pred_idx]

loss_f, acc_f = model.evaluate(dataset)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 2s 27ms/step - loss: 0.3622 - accuracy: 0.8065
# Epoch 2/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3917 - accuracy: 0.8172
# Epoch 3/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3095 - accuracy: 0.8817
# Epoch 4/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3473 - accuracy: 0.8710
# Epoch 5/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3856 - accuracy: 0.8387
# Epoch 6/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.4963 - accuracy: 0.7634
# Epoch 7/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3979 - accuracy: 0.8172
# Epoch 8/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3563 - accuracy: 0.8172
# Epoch 9/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.5067 - accuracy: 0.7849
# Epoch 10/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3473 - accuracy: 0.8280
# Epoch 11/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.4764 - accuracy: 0.7849
# Epoch 12/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3748 - accuracy: 0.7957
# Epoch 13/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3856 - accuracy: 0.8065
# Epoch 14/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.4135 - accuracy: 0.8172
# Epoch 15/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.4657 - accuracy: 0.8065
# Epoch 16/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3259 - accuracy: 0.8280
# Epoch 17/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3820 - accuracy: 0.8495
# Epoch 18/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3145 - accuracy: 0.8172
# Epoch 19/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.4474 - accuracy: 0.7742
# Epoch 20/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.5024 - accuracy: 0.7957
# Epoch 21/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3118 - accuracy: 0.8495
# Epoch 22/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.4473 - accuracy: 0.8065
# Epoch 23/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3914 - accuracy: 0.8065
# Epoch 24/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3620 - accuracy: 0.8387
# Epoch 25/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.4482 - accuracy: 0.7849
# Epoch 26/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3051 - accuracy: 0.8172
# Epoch 27/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2477 - accuracy: 0.8710
# Epoch 28/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3932 - accuracy: 0.8065
# Epoch 29/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2809 - accuracy: 0.8172
# Epoch 30/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3203 - accuracy: 0.8280
# Epoch 31/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3557 - accuracy: 0.8280
# Epoch 32/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3946 - accuracy: 0.8065
# Epoch 33/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3529 - accuracy: 0.8602
# Epoch 34/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3544 - accuracy: 0.8280
# Epoch 35/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2308 - accuracy: 0.9247
# Epoch 36/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3337 - accuracy: 0.8495
# Epoch 37/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3119 - accuracy: 0.8280
# Epoch 38/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3146 - accuracy: 0.8602
# Epoch 39/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2772 - accuracy: 0.8602
# Epoch 40/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2608 - accuracy: 0.8280
# Epoch 41/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3298 - accuracy: 0.8495
# Epoch 42/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3384 - accuracy: 0.7957
# Epoch 43/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2548 - accuracy: 0.8495
# Epoch 44/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3252 - accuracy: 0.8280
# Epoch 45/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3764 - accuracy: 0.8065
# Epoch 46/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3659 - accuracy: 0.7957
# Epoch 47/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2714 - accuracy: 0.8925
# Epoch 48/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2888 - accuracy: 0.8495
# Epoch 49/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.3455 - accuracy: 0.8280
# Epoch 50/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.2538 - accuracy: 0.8602
# 1/1 [==============================] - 0s 136ms/step
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2285 - accuracy: 0.8495

# %%
acc_fine = history_fine.history['accuracy']
loss_fine = history_fine.history['loss']

epochs_fine_range = range(len(acc_fine))

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_fine_range, acc_fine, label='fine-tuning Accuracy')
plt.legend(loc='lower right')
plt.title('Fine-tuning Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_fine_range, loss_fine, label='fine-tuning Loss')
plt.legend(loc='upper right')
plt.title('Fine-tuning Loss')
plt.show()

# %%
print("Evaluating model on the small-scale 'img' test dataset...")
loss_small, accuracy_small = model.evaluate(dataset)

print(f"Small-scale Test Loss: {loss_small:.4f}")
print(f"Small-scale Test Accuracy: {accuracy_small:.4f}")
# Out:
# Evaluating model on the small-scale 'img' test dataset...
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2285 - accuracy: 0.8495
# Small-scale Test Loss: 0.2285
# Small-scale Test Accuracy: 0.8495
