# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt

dataset_path = 'E:\project\img'     

try:
    image_height = 100
    image_width = 200
    batch_size = 8
    
    dataset = tf.keras.utils.image_dataset_from_directory(
        dataset_path,
        labels='inferred',
        label_mode='categorical',
        image_size=(image_height, image_width),
        interpolation='lanczos3',
        batch_size=batch_size,
        shuffle=True,
        seed=42
    ) 

    print(f"Total batches: {len(dataset)}") 
    
    plt.figure(figsize=(10, 10))
    for images, labels in dataset.take(1):
        for i in range(min(9, len(images))):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            predicted_class_index = np.argmax(labels[i].numpy())
            plt.title(dataset.class_names[predicted_class_index])
            plt.axis("off")
    plt.show() 

except Exception as e:
    print(f"error {e}")
# Out:
# Found 93 files belonging to 9 classes.
# Total batches: 12

# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt

base_dataset_path = 'E:\\project\\dataset'

image_height = 100
image_width = 200
batch_size = 8

def load_dataset_split_main(split_name, label_mode='categorical'):
    split_path = os.path.join(base_dataset_path, split_name, 'images')
    if not os.path.exists(split_path):
        print(f"Warning: Split path '{split_path}' not found. Skipping {split_name} dataset loading.")
        return None

    print(f"Loading {split_name} dataset from: {split_path}")
    dataset = tf.keras.utils.image_dataset_from_directory(
        split_path,
        labels='inferred',
        label_mode=label_mode,
        image_size=(image_height, image_width),
        interpolation='lanczos3',
        batch_size=batch_size,
        shuffle=(split_name == 'train'),
        seed=42 if split_name == 'train' else None
    )
    print(f"  {split_name} dataset created with {len(dataset.class_names)} classes: {dataset.class_names}")
    print(f"  Total batches: {len(dataset)}")
    return dataset

train_ds_full = load_dataset_split_main('train')
val_ds_full = load_dataset_split_main('val')
test_ds_full = load_dataset_split_main('test')


if train_ds_full:
    class_names = train_ds_full.class_names
    num_classes = len(class_names)
else:
    class_names = []
    num_classes = 0

if train_ds_full:
    plt.figure(figsize=(12, 12))
    plt.suptitle("Sample Images")

    selected_images = []
    selected_labels = []
    found_classes = set()

    for images, labels in train_ds_full.take(num_classes * 2):
        for i in range(len(images)):
            predicted_class_index = np.argmax(labels[i].numpy())
            class_name = class_names[predicted_class_index]

            if class_name not in found_classes:
                selected_images.append(images[i].numpy().astype("uint8"))
                selected_labels.append(class_name)
                found_classes.add(class_name)

            if len(found_classes) == num_classes:
                break
        if len(found_classes) == num_classes:
            break


    for i in range(min(num_classes, len(selected_images))):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(selected_images[i])
        plt.title(selected_labels[i])
        plt.axis("off")
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
# Out:
# Loading train dataset from: E:\project\dataset\train\images
# Found 431973 files belonging to 9 classes.
#   train dataset created with 9 classes: ['CLEAN', 'CROSS', 'DIAGONAL', 'DOUBLE_LINE', 'MIXED', 'SCRATCH', 'SINGLE_LINE', 'WAVE', 'ZIG_ZAG']
#   Total batches: 53997
# Loading val dataset from: E:\project\dataset\val\images
# Found 68031 files belonging to 9 classes.
#   val dataset created with 9 classes: ['CLEAN', 'CROSS', 'DIAGONAL', 'DOUBLE_LINE', 'MIXED', 'SCRATCH', 'SINGLE_LINE', 'WAVE', 'ZIG_ZAG']
#   Total batches: 8504
# Loading test dataset from: E:\project\dataset\test\images
# Found 182754 files belonging to 9 classes.
#   test dataset created with 9 classes: ['CLEAN', 'CROSS', 'DIAGONAL', 'DOUBLE_LINE', 'MIXED', 'SCRATCH', 'SINGLE_LINE', 'WAVE', 'ZIG_ZAG']
#   Total batches: 22845

# %%
dataset_size = len(dataset)
train_size = int(0.7 * dataset_size)
val_size = int(0.15 * dataset_size)
test_size = dataset_size - train_size - val_size

train_ds = dataset.take(train_size)
remaining_ds = dataset.skip(train_size)
val_ds = remaining_ds.take(val_size)
test_ds = remaining_ds.skip(val_size)

print(f"Dataset split into: ")
print(f"  Training: {len(train_ds)} batches")
print(f"  Validation: {len(val_ds)} batches")
print(f"  Test: {len(test_ds)} batches")
# Out:
# Dataset split into:
#   Training: 8 batches
#   Validation: 1 batches
#   Test: 3 batches

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Prepare the full datasets with caching and prefetching
train_ds_full = train_ds_full.shuffle(100).prefetch(buffer_size=AUTOTUNE)
val_ds_full = val_ds_full.prefetch(buffer_size=AUTOTUNE)
test_ds_full = test_ds_full.prefetch(buffer_size=AUTOTUNE)

print("Full datasets prepared with caching and prefetching.")
# Out:
# Full datasets prepared with caching and prefetching.

# %%
import tensorflow as tf

tf.keras.mixed_precision.set_global_policy('mixed_float16')
num_classes = len(class_names) # Correctly use class_names from the full dataset
print(f"Number of classes for model output: {num_classes}")

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255, input_shape=(image_height, image_width, 3)),
  tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   NVIDIA GeForce GTX 1060 6GB, compute capability 6.1
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# Number of classes for model output: 9
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 100, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 200, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 50, 100, 16)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 100, 32)       4640
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 50, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 50, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 25, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 19200)             0
#
#  dense (Dense)               (None, 128)               2457728
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 2,482,473
# Trainable params: 2,482,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

print("Verzió:", tf.__version__)
print("Elérhető eszközök:", tf.config.list_physical_devices())
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print(f"GPU elérhető: {gpu_devices}")
else:
    print("A TensorFlow NEM látja a GPU-t. CPU-n fog futni.")
# Out:
# Verzió: 2.10.0
# Elérhető eszközök: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU elérhető: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
epochs = 10
history = model.fit(
    train_ds_full,
    validation_data=val_ds_full,
    epochs=epochs
)

print("Model training complete with full dataset.")
# Out:
# Epoch 1/10
# 53997/53997 [==============================] - 1188s 22ms/step - loss: 0.7929 - accuracy: 0.7120 - val_loss: 0.7416 - val_accuracy: 0.7299
# Epoch 2/10
# 53997/53997 [==============================] - 854s 16ms/step - loss: 0.6935 - accuracy: 0.7493 - val_loss: 0.8187 - val_accuracy: 0.7126
# Epoch 3/10
# 53997/53997 [==============================] - 855s 16ms/step - loss: 0.6751 - accuracy: 0.7566 - val_loss: 0.7345 - val_accuracy: 0.7367
# Epoch 4/10
# 53997/53997 [==============================] - 855s 16ms/step - loss: 0.6685 - accuracy: 0.7594 - val_loss: 0.7535 - val_accuracy: 0.7338
# Epoch 5/10
# 53997/53997 [==============================] - 842s 16ms/step - loss: 0.6659 - accuracy: 0.7601 - val_loss: 0.7904 - val_accuracy: 0.7173
# Epoch 6/10
# 53997/53997 [==============================] - 814s 15ms/step - loss: 0.6663 - accuracy: 0.7599 - val_loss: 0.7518 - val_accuracy: 0.7323
# Epoch 7/10
# 53997/53997 [==============================] - 813s 15ms/step - loss: 0.6677 - accuracy: 0.7598 - val_loss: 0.7606 - val_accuracy: 0.7348
# Epoch 8/10
# 53997/53997 [==============================] - 816s 15ms/step - loss: 0.6676 - accuracy: 0.7599 - val_loss: 0.8142 - val_accuracy: 0.7113
# Epoch 9/10
# 53997/53997 [==============================] - 819s 15ms/step - loss: 0.6698 - accuracy: 0.7596 - val_loss: 0.7542 - val_accuracy: 0.7322
# Epoch 10/10
# 53997/53997 [==============================] - 834s 15ms/step - loss: 0.6745 - accuracy: 0.7586 - val_loss: 0.7974 - val_accuracy: 0.7223
# Model training complete with full dataset.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='training accuracy')
plt.plot(epochs_range, val_acc, label='validation accuracy')
plt.legend(loc='lower right')
plt.title('training and validation accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='training loss')
plt.plot(epochs_range, val_loss, label='validation loss')
plt.legend(loc='upper right')
plt.title('training and validation loss')
plt.show()

# %%
print("Evaluating model on the test dataset...")
loss, accuracy = model.evaluate(test_ds_full)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Evaluating model on the test dataset...
# 22845/22845 [==============================] - 370s 16ms/step - loss: 0.7550 - accuracy: 0.7372
# Test Loss: 0.7550
# Test Accuracy: 0.7372

# %%
print("Evaluating model on the small-scale 'img' test dataset...")
loss_small, accuracy_small = model.evaluate(dataset)

print(f"Small-scale Test Loss: {loss_small:.4f}")
print(f"Small-scale Test Accuracy: {accuracy_small:.4f}")
# Out:
# Evaluating model on the small-scale 'img' test dataset...
# 12/12 [==============================] - 0s 8ms/step - loss: 2.0414 - accuracy: 0.2151
# Small-scale Test Loss: 2.0414
# Small-scale Test Accuracy: 0.2151

# %%
import numpy as np
import tensorflow as tf

tf.keras.mixed_precision.set_global_policy('float32')
num_classes_model = model.layers[-1].output_shape[-1]
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

dataset_shuffled = dataset.shuffle(buffer_size=64)

history_fine = model.fit(
    dataset_shuffled,
    epochs=50,
    verbose=1
)

for images, labels in dataset_shuffled.take(1):
    preds = model.predict(images)
    for i in range(min(5, len(images))):
        true_idx = np.argmax(labels[i])
        pred_idx = np.argmax(preds[i])
        conf = preds[i][pred_idx]

loss_f, acc_f = model.evaluate(dataset)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 2s 17ms/step - loss: 2.0301 - accuracy: 0.2151
# Epoch 2/50
# 12/12 [==============================] - 0s 16ms/step - loss: 1.8570 - accuracy: 0.3118
# Epoch 3/50
# 12/12 [==============================] - 0s 14ms/step - loss: 1.8217 - accuracy: 0.2903
# Epoch 4/50
# 12/12 [==============================] - 0s 14ms/step - loss: 1.7793 - accuracy: 0.3441
# Epoch 5/50
# 12/12 [==============================] - 0s 13ms/step - loss: 1.6423 - accuracy: 0.3871
# Epoch 6/50
# 12/12 [==============================] - 0s 13ms/step - loss: 1.4782 - accuracy: 0.3656
# Epoch 7/50
# 12/12 [==============================] - 0s 13ms/step - loss: 1.3710 - accuracy: 0.4409
# Epoch 8/50
# 12/12 [==============================] - 0s 13ms/step - loss: 1.2692 - accuracy: 0.5054
# Epoch 9/50
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1597 - accuracy: 0.5161
# Epoch 10/50
# 12/12 [==============================] - 0s 13ms/step - loss: 1.0832 - accuracy: 0.5806
# Epoch 11/50
# 12/12 [==============================] - 0s 13ms/step - loss: 1.0281 - accuracy: 0.6129
# Epoch 12/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.9414 - accuracy: 0.7097
# Epoch 13/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.8821 - accuracy: 0.7204
# Epoch 14/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.8081 - accuracy: 0.7419
# Epoch 15/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7525 - accuracy: 0.7204
# Epoch 16/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.7643 - accuracy: 0.7419
# Epoch 17/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.7734 - accuracy: 0.6989
# Epoch 18/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.6827 - accuracy: 0.7419
# Epoch 19/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.6290 - accuracy: 0.7634
# Epoch 20/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.6044 - accuracy: 0.7957
# Epoch 21/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5670 - accuracy: 0.7957
# Epoch 22/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.5365 - accuracy: 0.8065
# Epoch 23/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4880 - accuracy: 0.8065
# Epoch 24/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4776 - accuracy: 0.8172
# Epoch 25/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4521 - accuracy: 0.7957
# Epoch 26/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4527 - accuracy: 0.7957
# Epoch 27/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4454 - accuracy: 0.8280
# Epoch 28/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4383 - accuracy: 0.8280
# Epoch 29/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4383 - accuracy: 0.8387
# Epoch 30/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.4158 - accuracy: 0.8172
# Epoch 31/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3997 - accuracy: 0.8172
# Epoch 32/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3943 - accuracy: 0.8280
# Epoch 33/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3822 - accuracy: 0.8280
# Epoch 34/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3864 - accuracy: 0.7957
# Epoch 35/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3891 - accuracy: 0.8387
# Epoch 36/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3758 - accuracy: 0.8387
# Epoch 37/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3822 - accuracy: 0.7742
# Epoch 38/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3837 - accuracy: 0.8065
# Epoch 39/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3738 - accuracy: 0.8065
# Epoch 40/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3725 - accuracy: 0.8172
# Epoch 41/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3674 - accuracy: 0.8172
# Epoch 42/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3669 - accuracy: 0.7849
# Epoch 43/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3666 - accuracy: 0.7742
# Epoch 44/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3541 - accuracy: 0.8172
# Epoch 45/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3562 - accuracy: 0.7742
# Epoch 46/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3646 - accuracy: 0.7849
# Epoch 47/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3551 - accuracy: 0.7957
# Epoch 48/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3908 - accuracy: 0.7957
# Epoch 49/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3530 - accuracy: 0.8172
# Epoch 50/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3682 - accuracy: 0.8280
# 1/1 [==============================] - 0s 215ms/step
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3481 - accuracy: 0.8280

# %%
acc_fine = history_fine.history['accuracy']
loss_fine = history_fine.history['loss']

epochs_fine_range = range(len(acc_fine))

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_fine_range, acc_fine, label='fine-tuning Accuracy')
plt.legend(loc='lower right')
plt.title('Fine-tuning Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_fine_range, loss_fine, label='fine-tuning Loss')
plt.legend(loc='upper right')
plt.title('Fine-tuning Loss')
plt.show()

# %%
print("Evaluating model on the small-scale 'img' test dataset...")
loss_small, accuracy_small = model.evaluate(dataset)

print(f"Small-scale Test Loss: {loss_small:.4f}")
print(f"Small-scale Test Accuracy: {accuracy_small:.4f}")
# Out:
# Evaluating model on the small-scale 'img' test dataset...
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3480 - accuracy: 0.8280
# Small-scale Test Loss: 0.3480
# Small-scale Test Accuracy: 0.8280
